# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Definicion del vector de tiempo
t = np.linspace(-5, 6, 4000)
dt = t[1] - t[0]

# 2. Ecuacion de la señal (Pulso rectangular)
y_a = np.where((t >= 0) & (t <= 2), 1.0, 0.0)

# 3. Transformada Rapida de Fourier (FFT)
Y_a = np.fft.fft(y_a) * dt
Y_a_centrada = np.fft.fftshift(Y_a)
frecuencias = np.fft.fftshift(np.fft.fftfreq(len(t), d=dt))

# 4. Graficacion
plt.plot(frecuencias, np.abs(Y_a_centrada), 'r-')
plt.title("|F(w)| de Pulso Rectangular")
plt.xlabel("Frecuencia (Hz)")
plt.ylabel("Magnitud")
plt.xlim(-3, 3)
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Definicion del vector de tiempo
t = np.linspace(-5, 6, 4000)
dt = t[1] - t[0]

# 2. Ecuacion de la señal (Pulso coseno)
y_b = np.where((t >= -1) & (t <= 1), np.cos(np.pi * t), 0.0)

# 3. Transformada Rapida de Fourier (FFT)
Y_b = np.fft.fft(y_b) * dt
Y_b_centrada = np.fft.fftshift(Y_b)
frecuencias = np.fft.fftshift(np.fft.fftfreq(len(t), d=dt))

# 4. Graficacion
plt.plot(frecuencias, np.abs(Y_b_centrada), 'r-')
plt.title("|F(w)| de Pulso Coseno")
plt.xlabel("Frecuencia (Hz)")
plt.ylabel("Magnitud")
plt.xlim(-5, 5) # Rango ampliado para ver mejor los lobulos
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Definicion del vector de tiempo
t = np.linspace(-5, 6, 4000)
dt = t[1] - t[0]

# 2. Ecuacion de la señal (Escalon asimetrico)
y_c = np.where((t >= -1) & (t < 0), 1.0, 
      np.where((t >= 0) & (t <= 1), -1.0, 0.0))

# 3. Transformada Rapida de Fourier (FFT)
Y_c = np.fft.fft(y_c) * dt
Y_c_centrada = np.fft.fftshift(Y_c)
frecuencias = np.fft.fftshift(np.fft.fftfreq(len(t), d=dt))

# 4. Graficacion
plt.plot(frecuencias, np.abs(Y_c_centrada), 'r-')
plt.title("|F(w)| de Escalon Asimetrico")
plt.xlabel("Frecuencia (Hz)")
plt.ylabel("Magnitud")
plt.xlim(-5, 5)
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Definicion del vector de tiempo
t = np.linspace(-5, 6, 4000)
dt = t[1] - t[0]

# 2. Ecuacion de la señal (Pulsos escalonados)
y_d = np.where((t >= 0) & (t < 2), 1.0, 
      np.where((t >= 2) & (t < 4), 2.0, 
      np.where((t >= 4) & (t <= 5), -1.0, 0.0)))

# 3. Transformada Rapida de Fourier (FFT)
Y_d = np.fft.fft(y_d) * dt
Y_d_centrada = np.fft.fftshift(Y_d)
frecuencias = np.fft.fftshift(np.fft.fftfreq(len(t), d=dt))

# 4. Graficacion
plt.plot(frecuencias, np.abs(Y_d_centrada), 'r-')
plt.title("|F(w)| de Pulsos Escalonados")
plt.xlabel("Frecuencia (Hz)")
plt.ylabel("Magnitud")
plt.xlim(-5, 5)
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Definicion del vector de tiempo
t = np.linspace(-5, 6, 4000)
dt = t[1] - t[0]

# 2. Ecuacion de la señal (Diente de sierra)
y_e = np.where((t >= -1) & (t <= 1), t, 0.0)

# 3. Transformada Rapida de Fourier (FFT)
Y_e = np.fft.fft(y_e) * dt
Y_e_centrada = np.fft.fftshift(Y_e)
frecuencias = np.fft.fftshift(np.fft.fftfreq(len(t), d=dt))

# 4. Graficacion
plt.plot(frecuencias, np.abs(Y_e_centrada), 'r-')
plt.title("|F(w)| de Diente de Sierra")
plt.xlabel("Frecuencia (Hz)")
plt.ylabel("Magnitud")
plt.xlim(-5, 5)
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Definicion del vector de tiempo
t = np.linspace(-5, 6, 4000)
dt = t[1] - t[0]

# 2. Ecuacion de la señal (Rampa truncada asimetrica)
y_f = np.where((t >= -1) & (t <= 1), 2*t - 3, 0.0)

# 3. Transformada Rapida de Fourier (FFT)
Y_f = np.fft.fft(y_f) * dt
Y_f_centrada = np.fft.fftshift(Y_f)
frecuencias = np.fft.fftshift(np.fft.fftfreq(len(t), d=dt))

# 4. Graficacion
plt.plot(frecuencias, np.abs(Y_f_centrada), 'r-')
plt.title("|F(w)| de Rampa Truncada Asimetrica")
plt.xlabel("Frecuencia (Hz)")
plt.ylabel("Magnitud")
plt.xlim(-5, 5)
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Definicion del vector de tiempo
t = np.linspace(-5, 6, 4000)
dt = t[1] - t[0]

# 2. Ecuacion de la señal (Pulso triangular)
y_g = np.where((t >= -2) & (t < 0), t + 2, 
      np.where((t >= 0) & (t <= 2), -t + 2, 0.0))

# 3. Transformada Rapida de Fourier (FFT)
Y_g = np.fft.fft(y_g) * dt
Y_g_centrada = np.fft.fftshift(Y_g)
frecuencias = np.fft.fftshift(np.fft.fftfreq(len(t), d=dt))

# 4. Graficacion
plt.plot(frecuencias, np.abs(Y_g_centrada), 'r-')
plt.title("|F(w)| de Pulso Triangular")
plt.xlabel("Frecuencia (Hz)")
plt.ylabel("Magnitud")
plt.xlim(-3, 3)
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Definicion del vector de tiempo
t = np.linspace(-5, 6, 4000)
dt = t[1] - t[0]

# 2. Ecuacion de la señal (Rampa saturada)
y_h = np.where((t >= -1) & (t <= 1), t + 1, 
      np.where((t > 1) & (t <= 2), 2.0, 0.0))

# 3. Transformada Rapida de Fourier (FFT)
Y_h = np.fft.fft(y_h) * dt
Y_h_centrada = np.fft.fftshift(Y_h)
frecuencias = np.fft.fftshift(np.fft.fftfreq(len(t), d=dt))

# 4. Graficacion
plt.plot(frecuencias, np.abs(Y_h_centrada), 'r-')
plt.title("|F(w)| de Rampa Saturada")
plt.xlabel("Frecuencia (Hz)")
plt.ylabel("Magnitud")
plt.xlim(-5, 5)
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definición de vectores de tiempo y frecuencia (omega)
t = np.linspace(-1, 5, 1000)
w = np.linspace(-15, 15, 1000)

# Señal en el tiempo
u_t_minus_1 = np.heaviside(t - 1, 1)
x1_t = np.exp(-3 * t) * u_t_minus_1

# Espectro de Magnitud |X1(w)|
X1_w = np.exp(-(3 + 1j * w)) / (3 + 1j * w)
X1_mag = np.abs(X1_w)

plt.figure(figsize=(12, 10))

# Gráfica Señal 1 en el tiempo
plt.subplot(2, 2, 1)
plt.plot(t, x1_t, 'b-', label='$x_1(t) = e^{-3t}u(t-1)$')
plt.title('Señal 1')
plt.xlabel('Tiempo (t)')
plt.ylabel('Amplitud')
plt.grid(True)
plt.legend()

# Gráfica Magnitud Transformada 1
plt.subplot(2, 2, 2)
plt.plot(w, X1_mag, 'r-', label='$|X_1(\omega)|$')
plt.title('Transformada de Fourier de la Señal 1')
plt.xlabel('Frecuencia ($\omega$) [rad/s]')
plt.ylabel('Magnitud')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# <>:29: SyntaxWarning: invalid escape sequence '\o'
# <>:31: SyntaxWarning: invalid escape sequence '\o'
# <>:29: SyntaxWarning: invalid escape sequence '\o'
# <>:31: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\julio\AppData\Local\Temp\ipykernel_26128\3105431847.py:29: SyntaxWarning: invalid escape sequence '\o'
#   plt.plot(w, X1_mag, 'r-', label='$|X_1(\omega)|$')
# C:\Users\julio\AppData\Local\Temp\ipykernel_26128\3105431847.py:31: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('Frecuencia ($\omega$) [rad/s]')

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(-1, 5, 1000)
w = np.linspace(-15, 15, 1000)

# Señal en el tiempo
u_t = np.heaviside(t, 1)
x2_t = t * np.exp(-2 * t) * u_t

# Transformada de Fourier |X2(w)|
X2_w = 1 / (2 + 1j * w)**2
X2_mag = np.abs(X2_w)

plt.figure(figsize=(12, 10))

# Gráfica Señal 2 en el tiempo
plt.subplot(2, 2, 3)
plt.plot(t, x2_t, 'g-', label='$x_2(t) = t e^{-2t}u(t)$')
plt.title('Señal 2')
plt.xlabel('Tiempo (t)')
plt.ylabel('Amplitud')
plt.grid(True)
plt.legend()

# Gráfica Transformada 
plt.subplot(2, 2, 4)
plt.plot(w, X2_mag, 'm-', label='$|X_2(\omega)|$')
plt.title('Tranformada de Fourier de la Señal 2')
plt.xlabel('Frecuencia ($\omega$) [rad/s]')
plt.ylabel('Magnitud')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# <>:28: SyntaxWarning: invalid escape sequence '\o'
# <>:30: SyntaxWarning: invalid escape sequence '\o'
# <>:28: SyntaxWarning: invalid escape sequence '\o'
# <>:30: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\julio\AppData\Local\Temp\ipykernel_26128\280716405.py:28: SyntaxWarning: invalid escape sequence '\o'
#   plt.plot(w, X2_mag, 'm-', label='$|X_2(\omega)|$')
# C:\Users\julio\AppData\Local\Temp\ipykernel_26128\280716405.py:30: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('Frecuencia ($\omega$) [rad/s]')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definición de dominios de tiempo y frecuencia
t = np.linspace(-3, 4, 1000)
w = np.linspace(-20, 20, 1000)

# Dominio del tiempo
u_t = np.heaviside(t, 1)
x1_t = np.exp(-3 * t) * np.cos(np.pi * t) * u_t

# Dominio de la frecuencia (Espectro de Magnitud)
X1_w = (3 + 1j * w) / ((3 + 1j * w)**2 + np.pi**2)
X1_mag = np.abs(X1_w)

plt.figure(figsize=(12, 10))

# Subplot 1: Señal 3 en el tiempo
plt.subplot(2, 2, 1)
plt.plot(t, x1_t, 'b-', label=r'$x_1(t) = e^{-3t}\cos(\pi t)u(t)$')
plt.title('Señal 3')
plt.xlabel('Tiempo (t) [s]')
plt.ylabel('Amplitud')
plt.grid(True)
plt.legend()

# Subplot 2: Magnitud Transformada 3
plt.subplot(2, 2, 2)
plt.plot(w, X1_mag, 'r-', label=r'$|X_1(\omega)|$')
plt.title('Trasnformada de Fourier - Señal 3')
plt.xlabel(r'Frecuencia ($\omega$) [rad/s]')
plt.ylabel('Magnitud')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definición de dominios de tiempo y frecuencia
t = np.linspace(-3, 4, 1000)
w = np.linspace(-20, 20, 1000)

# Dominio del tiempo
u_neg_t = np.heaviside(-t + 2, 1)
x2_t = np.exp(1 + t) * u_neg_t

# Dominio de la frecuencia (Espectro de Magnitud)
X2_w = np.exp(3 - 2j * w) / (1 - 1j * w)
X2_mag = np.abs(X2_w)

plt.figure(figsize=(12, 10))

# Subplot 3: Señal 2 en el tiempo
plt.subplot(2, 2, 3)
plt.plot(t, x2_t, 'g-', label=r'$x_2(t) = e^{1+t}u(-t+2)$')
plt.title('Señal 4')
plt.xlabel('Tiempo (t) [s]')
plt.ylabel('Amplitud')
plt.grid(True)
plt.legend()

# Subplot 4: Magnitud Transformada 2
plt.subplot(2, 2, 4)
plt.plot(w, X2_mag, 'm-', label=r'$|X_2(\omega)|$')
plt.title('Tranformada de Fourier - Señal 4')
plt.xlabel(r'Frecuencia ($\omega$) [rad/s]')
plt.ylabel('Magnitud')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Parámetros del tiempo y señales
fs = 20000  # Frecuencia de muestreo (20 kHz)
t = np.arange(0, 0.03, 1/fs)  # 30 ms

# Componentes
x0 = 10 * np.sin(2 * np.pi * 100 * t + np.deg2rad(50))     # 100 Hz
r1 = 5 * np.sin(2 * np.pi * 1000 * t + np.deg2rad(10))     # 1000 Hz
r2 = 5 * np.sin(2 * np.pi * 1500 * t + np.deg2rad(20))     # 1500 Hz
r3 = 5 * np.sin(2 * np.pi * 2000 * t + np.deg2rad(30))     # 2000 Hz

# Entrada total
x_in = x0 + r1 + r2 + r3

# 2. Respuesta del Filtro RC en el dominio del tiempo 
#filtrado analítico
fc = 205
H_100  = 1 / np.sqrt(1 + (100/fc)**2)
H_1000 = 1 / np.sqrt(1 + (1000/fc)**2)
H_1500 = 1 / np.sqrt(1 + (1500/fc)**2)
H_2000 = 1 / np.sqrt(1 + (2000/fc)**2)

# Desfases teóricos: phi = -arctan(f / fc)
phi_100  = -np.arctan(100/fc)
phi_1000 = -np.arctan(1000/fc)
phi_1500 = -np.arctan(1500/fc)
phi_2000 = -np.arctan(2000/fc)

# Señal de salida filtrada
y_out = (10 * H_100  * np.sin(2 * np.pi * 100 * t  + np.deg2rad(50) + 
         phi_100) +
         5  * H_1000 * np.sin(2 * np.pi * 1000 * t + np.deg2rad(10) + 
         phi_1000) +
         5  * H_1500 * np.sin(2 * np.pi * 1500 * t + np.deg2rad(20) + 
         phi_1500) +
         5  * H_2000 * np.sin(2 * np.pi * 2000 * t + np.deg2rad(30) + 
         phi_2000))

# 3. Creación de figura con dos subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Subplot 1: Dominio del tiempo
ax1.plot(t * 1000, x_in, label='Entrada: Señal ruidosa $x(t)$', 
color='gray', alpha=0.7)
ax1.plot(t * 1000, y_out, label='Salida: Señal recuperada $y(t)$', 
color='red', linewidth=2)
ax1.set_title('Comparación en el Dominio del Tiempo (0 a 30 ms)')
ax1.set_xlabel('Tiempo [ms]')
ax1.set_ylabel('Amplitud [V]')
ax1.grid(True, linestyle='--', alpha=0.6)
ax1.legend(loc='upper right')

# Subplot 2: Diagrama de Bode (Respuesta en Frecuencia)
freqs = np.logspace(1, 4, 500)
ganancia = 1 / np.sqrt(1 + (freqs / fc)**2)

ax2.semilogx(freqs, ganancia, color='blue', linewidth=2, 
label='Respuesta $|H(f)|$')
ax2.plot(100, H_100, 'go', label=f'100 Hz (Ganancia: {H_100:.3f})')
ax2.plot(fc, 1/np.sqrt(2), 'ro', label=f'fc = {fc} Hz (-3dB)')
ax2.plot(1000, H_1000, 'mo', label=f'1000 Hz (Ganancia: {H_1000:.3f})')

ax2.set_title('Respuesta en Frecuencia del Filtro (Diagrama de Bode)')
ax2.set_xlabel('Frecuencia [Hz]')
ax2.set_ylabel('Ganancia Magnitude')
ax2.grid(True, which='both', linestyle='--', alpha=0.5)
ax2.legend(loc='lower left')

plt.tight_layout()
plt.show()

# %%
# Filtros pasa-altos de primer orden en cascada (2000Hz)
import numpy as np
import matplotlib.pyplot as plt

# 1. Parámetros del tiempo y señales
fs = 20000   # Frecuencia de muestreo (20 kHz)
t = np.arange(0, 0.03, 1/fs)   # 30 ms

# Componentes originales de la señal contaminada
x0 = 10 * np.sin(2 * np.pi * 100 * t + np.deg2rad(50))      # 100 Hz
r1 = 5 * np.sin(2 * np.pi * 1000 * t + np.deg2rad(10))      # 1000 Hz
r2 = 5 * np.sin(2 * np.pi * 1500 * t + np.deg2rad(20))      # 1500 Hz
r3 = 5 * np.sin(2 * np.pi * 2000 * t + np.deg2rad(30))      # 2000 Hz (Señal de interés)

# Entrada total
x_in = x0 + r1 + r2 + r3

# 2. Respuesta de dos etapas de Filtro Pasa-Altos RC en cascada
# Frecuencia de corte individual de cada etapa (asumiendo etapas idénticas)
fc = 1800    # Frecuencia de corte [Hz]

# Para una etapa individual de filtro RC pasa-altos:
# Ganancia H1(f) = (f / fc) / sqrt(1 + (f / fc)^2) = 1 / sqrt(1 + (fc / f)^2)
# Desfase phi1(f) = arctan(fc / f)
def ganancia_etapa_hp(f, fc):
    return 1 / np.sqrt(1 + (fc / f)**2)

def desfase_etapa_hp(f, fc):
    return np.arctan(fc / f)

# Al conectar dos etapas idénticas en cascada (sin carga entre ellas, ej. usando un seguidor con Op-Amp):
# La ganancia total es el producto de las ganancias: H_total = H1 * H2 = H1^2
# El desfase total es la suma de los desfases: phi_total = phi1 + phi2 = 2 * phi1
def ganancia_total_hp2(f, fc):
    h = ganancia_etapa_hp(f, fc)
    return h * h

def desfase_total_hp2(f, fc):
    return 2 * desfase_etapa_hp(f, fc)

freqs_eval = [100, 1000, 1500, 2000]
H_vals = [ganancia_total_hp2(f, fc) for f in freqs_eval]
phi_vals = [desfase_total_hp2(f, fc) for f in freqs_eval]

H_100, H_1000, H_1500, H_2000 = H_vals
phi_100, phi_1000, phi_1500, phi_2000 = phi_vals

# Señal de salida filtrada combinando las amplitudes y desfasando cada componente
y_out = (10 * H_100   * np.sin(2 * np.pi * 100 * t   + np.deg2rad(50) + phi_100) +
         5  * H_1000  * np.sin(2 * np.pi * 1000 * t  + np.deg2rad(10) + phi_1000) +
         5  * H_1500  * np.sin(2 * np.pi * 1500 * t  + np.deg2rad(20) + phi_1500) +
         5  * H_2000  * np.sin(2 * np.pi * 2000 * t  + np.deg2rad(30) + phi_2000))

# 3. Creación de figura con dos subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Subplot 1: Dominio del tiempo
ax1.plot(t * 1000, x_in, label='Entrada: Señal contaminada $x(t)$', color='gray', alpha=0.7)
ax1.plot(t * 1000, y_out, label='Salida: Señal recuperada $y(t)$ (2 kHz)', color='purple', linewidth=2)
ax1.set_title('Filtro Pasa-Altos (2 Etapas RC en Cascada): Dominio del Tiempo (0 a 30 ms)')
ax1.set_xlabel('Tiempo [ms]')
ax1.set_ylabel('Amplitud [V]')
ax1.grid(True, linestyle='--', alpha=0.6)
ax1.legend(loc='upper right')

# Subplot 2: Diagrama de Bode (Respuesta en Frecuencia)
freqs = np.logspace(1, 4.2, 500)
ganancia_bode = [ganancia_total_hp2(f, fc) for f in freqs]

ax2.semilogx(freqs, ganancia_bode, color='blue', linewidth=2, label='Respuesta 2 Etapas Cascada $|H(f)|$')
ax2.plot(100, H_100, 'ko', label=f'100 Hz (Ganancia: {H_100:.3f})')
ax2.plot(1000, H_1000, 'mo', label=f'1000 Hz (Ganancia: {H_1000:.3f})')
ax2.plot(1500, H_1500, 'go', label=f'1500 Hz (Ganancia: {H_1500:.3f})')
ax2.plot(fc, (1/np.sqrt(2))**2, 'ro', label=f'fc = {fc} Hz (-6dB)')
ax2.plot(2000, H_2000, 'bo', label=f'2000 Hz (Ganancia: {H_2000:.3f})')

ax2.set_title('Respuesta en Frecuencia del Filtro (Diagrama de Bode)')
ax2.set_xlabel('Frecuencia [Hz]')
ax2.set_ylabel('Ganancia Magnitude')
ax2.grid(True, which='both', linestyle='--', alpha=0.5)
ax2.legend(loc='lower left')

plt.tight_layout()
plt.show()

# %%
# Comparacion con Filtro pasa-bajo (100Hz)
import numpy as np
import matplotlib.pyplot as plt

# 1. Parámetros del tiempo y señales
fs = 20000 # Frecuencia de muestreo (20 kHz)
t = np.arange(0, 0.03, 1/fs) # 30 ms

# Componentes
x0 = 10 * np.sin(2 * np.pi * 100 * t + np.deg2rad(50)) # 100 Hz
r1 = 5 * np.sin(2 * np.pi * 1000 * t + np.deg2rad(10)) # 1000 Hz
r2 = 5 * np.sin(2 * np.pi * 1500 * t + np.deg2rad(20)) # 1500 Hz
r3 = 5 * np.sin(2 * np.pi * 2000 * t + np.deg2rad(30)) # 2000 Hz

# Entrada total
x_in = x0 + r1 + r2 + r3

# 2. Respuesta del Filtro RC en el dominio del tiempo (filtrado analítico)
fc = 205
H_100  = 1 / np.sqrt(1 + (100/fc)**2)
H_1000 = 1 / np.sqrt(1 + (1000/fc)**2)
H_1500 = 1 / np.sqrt(1 + (1500/fc)**2)
H_2000 = 1 / np.sqrt(1 + (2000/fc)**2)

# Desfases teóricos: phi = -arctan(f / fc)
phi_100  = -np.arctan(100/fc)
phi_1000 = -np.arctan(1000/fc)
phi_1500 = -np.arctan(1500/fc)
phi_2000 = -np.arctan(2000/fc)

# Señal de salida filtrada
y_out = (10 * H_100  * np.sin(2 * np.pi * 100 * t  + np.deg2rad(50) + phi_100) +
         5  * H_1000 * np.sin(2 * np.pi * 1000 * t + np.deg2rad(10) + phi_1000) +
         5  * H_1500 * np.sin(2 * np.pi * 1500 * t + np.deg2rad(20) + phi_1500) +
         5  * H_2000 * np.sin(2 * np.pi * 2000 * t + np.deg2rad(30) + phi_2000))

# 3. Creación de figura con dos subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Subplot 1: Dominio del tiempo
ax1.plot(t * 1000, x_in, label='Entrada: Señal ruidosa $x(t)$', color='gray', alpha=0.7)
ax1.plot(t * 1000, y_out, label='Salida: Señal recuperada $y(t)$', color='red', linewidth=2)
ax1.set_title('Comparación en el Dominio del Tiempo (0 a 30 ms)')
ax1.set_xlabel('Tiempo [ms]')
ax1.set_ylabel('Amplitud [V]')
ax1.grid(True, linestyle='--', alpha=0.6)
ax1.legend(loc='upper right')

# Subplot 2: Diagrama de Bode (Respuesta en Frecuencia)
freqs = np.logspace(1, 4, 500)
ganancia = 1 / np.sqrt(1 + (freqs / fc)**2)

ax2.semilogx(freqs, ganancia, color='blue', linewidth=2, label='Respuesta $|H(f)|$')
ax2.plot(100, H_100, 'go', label=f'100 Hz (Ganancia: {H_100:.3f})')
ax2.plot(fc, 1/np.sqrt(2), 'ro', label=f'fc = {fc} Hz (-3dB)')
ax2.plot(1000, H_1000, 'mo', label=f'1000 Hz (Ganancia: {H_1000:.3f})')

ax2.set_title('Respuesta en Frecuencia del Filtro (Diagrama de Bode)')
ax2.set_xlabel('Frecuencia [Hz]')
ax2.set_ylabel('Ganancia Magnitude')
ax2.grid(True, which='both', linestyle='--', alpha=0.5)
ax2.legend(loc='lower left')

plt.tight_layout()
plt.show()
